# %%
print('Hello Python')
# Out:
# Hello Python

# %%
lTemp = ['a', 'a', 'b', 'a']
lTemp.remove('a')
print(lTemp)

sTemp = 'ABCD'
print(sTemp[2:10])
# Out:
# ['a', 'b', 'a']
# CD

# %% [markdown]
# # 문자열 관련 함수
