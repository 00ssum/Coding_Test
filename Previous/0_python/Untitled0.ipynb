# %% [markdown]
# 네트워크란 컴퓨터 상호 간에 정보를 교환할 수 있도록 연결된 형태를 의미합니다. 예를 들어, 컴퓨터 A와 컴퓨터 B가 직접적으로 연결되어있고, 컴퓨터 B와 컴퓨터 C가 직접적으로 연결되어 있을 때 컴퓨터 A와 컴퓨터 C도 간접적으로 연결되어 정보를 교환할 수 있습니다. 따라서 컴퓨터 A, B, C는 모두 같은 네트워크 상에 있다고 할 수 있습니다.
#
# 컴퓨터의 개수 n, 연결에 대한 정보가 담긴 2차원 배열 computers가 매개변수로 주어질 때, 네트워크의 개수를 return 하도록 solution 함수를 작성하시오.

# %%
def solution(n, computers):
    answer = 0
    dict_computer = dict()
    temp = set()

    for i, computer in enumerate(computers):
        dict_computer[i] = [idx for idx, c in enumerate(computer) if c == 1 if idx != i]

    print(dict_computer)
    for k in dict_computer.keys():
      print(k)
      print(temp)
      if k not in temp:
        temp.add(k)
        temp.update(set(bfs(dict_computer, k)))
        answer += 1
      if k in temp:
        print('in....')

    return answer

def bfs(graph, start_node):
  visited = []
  need_visit = [start_node]

  while need_visit:
    print(visited)
    node = need_visit.pop(0)
    if node not in visited:
      visited.append(node)
      need_visit.extend(graph[node])

  print('visited :: ' + str(visited))
  return visited

# %%
#solution(3, [[1, 1, 0], [1, 1, 0], [0, 0, 1]])
#print('===========================================')
solution(3, [[1, 1, 0], [1, 1, 1], [0, 1, 1]])
# Out:
# {0: [1], 1: [0, 2], 2: [1]}
# 0
# set()
# []
# [0]
# [0, 1]
# [0, 1]
# [0, 1, 2]
# visited :: [0, 1, 2]
# in....
# 1
# {0, 1, 2}
# in....
# 2
# {0, 1, 2}
# in....
# 1

# %%
def solution(begin, target, words):
    answer = 0
    temp_list = [i[1] for i in make_graph(begin, words) if i[0] == target]
    print(temp_list)

    return answer        

def make_graph(begin, words):
    visited = []
    need_visit = [(begin, 0)]

    while need_visit:
        node = need_visit.pop(0)
        if node[0] not in [i[0] for i in visited]:
            visited.append(node)
            need_visit.extend((j, node[1]+1) for j in can_connect(node[0], words) if j not in [i[0] for i in visited])
    print(visited)
    return visited


def can_connect(word1, words):
    result = []
    for word in words:
        count = 0
        for w1, w2 in zip(word1, word):
            if w1 != w2:
                count += 1

        if count == 1:
            result.append(word)
    return result
    


solution('hit','cog',["hot", "dot", "dog", "lot", "log", "cog"])
# Out:
# [('hit', 0), ('hot', 1), ('dot', 2), ('lot', 2), ('dog', 3), ('log', 3), ('cog', 4)]
# [4]
# 0

# %%
dict_temp = {}
dict_temp[0] = [1,2,3,4]
dict_temp[1] = [4,5,6,7]

ndict_temp = dict(dict_temp)

dict_temp[0].remove(1)
print(dict_temp)
print(ndict_temp)
# Out:
# {0: [2, 3, 4], 1: [4, 5, 6, 7]}
# {0: [2, 3, 4], 1: [4, 5, 6, 7]}

# %%
a = 1
a = '1'
print(ord('a'))
# Out:
# 97

# %%
import heapq
def solution(jobs):
    answer = []
    queue = []
    jobs.sort()
    now_time = 0
    heapq.heappush(queue, [jobs[0][1], jobs[0][0]])
    jobs.remove(jobs[0])

    while queue:
      print(f'queue :: {queue}')
      duration, start_time = heapq.heappop(queue)
      now_time = max(start_time, now_time) + duration
      answer.append(now_time - start_time)

      temp_job = []

      for job in jobs:
        if job[0] <= now_time:
          heapq.heappush(queue, [job[1], job[0]])
          temp_job.append(job)

      jobs = [j for j in jobs if j not in temp_job]
      if jobs and len(queue) == 0:
        heapq.heappush(queue, [jobs[0][1], jobs[0][0]])
        jobs.remove(jobs[0])


    print(answer)

    # solution = {1 + 2 + 3} / 3
    #while queue:



    return answer

solution([[0, 3], [1, 2], [2, 3], [15, 1]])
# Out:
# queue :: [[3, 0]]
# queue :: [[2, 1], [3, 2]]
# queue :: [[3, 2]]
# queue :: [[1, 15]]
# [3, 5, 8, 16]
# [3, 5, 8, 16]
